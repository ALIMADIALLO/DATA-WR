# 17                       Encounter for symptom            129.16
# 18  General examination of patient (procedure)            129.16
# 19        Emergency room admission (procedure)            129.16
# 20  General examination of patient (procedure)            129.16
# 21                       Encounter for symptom            129.16
# 22              Urgent care clinic (procedure)            129.16
# 23          Encounter for check up (procedure)            129.16
# 24                  Consultation for treatment            129.16
# 25                  Consultation for treatment            129.16
# 26                       Encounter for symptom            129.16
# 27                       Encounter for symptom            129.16
# 28                  Consultation for treatment            129.16
# 29  General examination of patient (procedure)            129.16
# 30                  Consultation for treatment            129.16
# 31                 Patient encounter procedure            129.16
# 32                 Patient encounter procedure            129.16
# 33                  Consultation for treatment            129.16
# 34  General examination of patient (procedure)            129.16
# 35                       Encounter for symptom            129.16
# 36                  Consultation for treatment            129.16
# 37                 Patient encounter procedure            129.16
# 38                  Consultation for treatment            129.16
# 39  General examination of patient (procedure)            129.16
# 40                  Consultation for treatment            129.16
# 41                Well child visit (procedure)            129.16
# 42                       Encounter for symptom            129.16
# 43                       Encounter for symptom            129.16
# 44                Well child visit (procedure)            129.16
# 45                       Encounter for symptom            129.16
# 46          Encounter for check up (procedure)            129.16
#
#     PAYER_COVERAGE                     REASONDESCRIPTION   BIRTHDATE  \
# 0            54.16           Acute bronchitis (disorder)  14/11/1983
# 1           129.16                                   NaN  14/11/1983
# 2           129.16                                   NaN  14/11/1983
# 3            54.16           Acute bronchitis (disorder)  14/11/1983
# 4            54.16                                   NaN  14/11/1983
# 5           129.16                                   NaN  14/11/1983
# 6             0.00                  Sinusitis (disorder)  25/05/1989
# 7             0.00                                   NaN  25/05/1989
# 8             0.00            Viral sinusitis (disorder)  25/05/1989
# 9             0.00                                   NaN  25/05/1989
# 10            0.00                                   NaN  25/05/1989
# 11            0.00            Viral sinusitis (disorder)  25/05/1989
# 12          129.16                                   NaN  02/06/1992
# 13           49.16           Acute bronchitis (disorder)  02/06/1992
# 14            0.00                                   NaN  02/06/1992
# 15          129.16                                   NaN  02/06/1992
# 16            0.00                                   NaN  02/06/1992
# 17           49.16            Viral sinusitis (disorder)  02/06/1992
# 18          129.16                                   NaN  02/06/1992
# 19           49.16                                   NaN  02/06/1992
# 20          129.16                                   NaN  02/06/1992
# 21           49.16           Acute bronchitis (disorder)  02/06/1992
# 22            0.00                                   NaN  02/06/1992
# 23            0.00                                   NaN  02/06/1992
# 24            0.00                                   NaN  27/05/1978
# 25            0.00                                   NaN  27/05/1978
# 26           64.16            Viral sinusitis (disorder)  27/05/1978
# 27           64.16    Acute viral pharyngitis (disorder)  27/05/1978
# 28            0.00                                   NaN  27/05/1978
# 29          129.16                                   NaN  27/05/1978
# 30            0.00                                   NaN  27/05/1978
# 31            0.00                                   NaN  27/05/1978
# 32            0.00                                   NaN  27/05/1978
# 33            0.00                                   NaN  27/05/1978
# 34          129.16                                   NaN  27/05/1978
# 35           64.16  Streptococcal sore throat (disorder)  27/05/1978
# 36            0.00                                   NaN  27/05/1978
# 37            0.00                                   NaN  27/05/1978
# 38            0.00                                   NaN  27/05/1978
# 39          129.16                                   NaN  27/05/1978
# 40            0.00                                   NaN  27/05/1978
# 41          129.16                                   NaN  18/10/1996
# 42           69.16    Acute viral pharyngitis (disorder)  18/10/1996
# 43           69.16    Acute viral pharyngitis (disorder)  18/10/1996
# 44          129.16                                   NaN  18/10/1996
# 45           69.16            Viral sinusitis (disorder)  18/10/1996
# 46            0.00                                   NaN  18/10/1996
#
#    DEATHDATE  ...    ETHNICITY GENDER                        BIRTHPLACE  \
# 0        NaN  ...  nonhispanic      M        Danvers  Massachusetts  US
# 1        NaN  ...  nonhispanic      M        Danvers  Massachusetts  US
# 2        NaN  ...  nonhispanic      M        Danvers  Massachusetts  US
# 3        NaN  ...  nonhispanic      M        Danvers  Massachusetts  US
# 4        NaN  ...  nonhispanic      M        Danvers  Massachusetts  US
# 5        NaN  ...  nonhispanic      M        Danvers  Massachusetts  US
# 6        NaN  ...     hispanic      M  Marigot  Saint Andrew Parish  DM
# 7        NaN  ...     hispanic      M  Marigot  Saint Andrew Parish  DM
# 8        NaN  ...     hispanic      M  Marigot  Saint Andrew Parish  DM
# 9        NaN  ...     hispanic      M  Marigot  Saint Andrew Parish  DM
# 10       NaN  ...     hispanic      M  Marigot  Saint Andrew Parish  DM
# 11       NaN  ...     hispanic      M  Marigot  Saint Andrew Parish  DM
# 12       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 13       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 14       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 15       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 16       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 17       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 18       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 19       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 20       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 21       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 22       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 23       NaN  ...  nonhispanic      M    Springfield  Massachusetts  US
# 24       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 25       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 26       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 27       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 28       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 29       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 30       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 31       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 32       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 33       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 34       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 35       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 36       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 37       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 38       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 39       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 40       NaN  ...  nonhispanic      F       Yarmouth  Massachusetts  US
# 41       NaN  ...  nonhispanic      M                Patras  Achaea  GR
# 42       NaN  ...  nonhispanic      M                Patras  Achaea  GR
# 43       NaN  ...  nonhispanic      M                Patras  Achaea  GR
# 44       NaN  ...  nonhispanic      M                Patras  Achaea  GR
# 45       NaN  ...  nonhispanic      M                Patras  Achaea  GR
# 46       NaN  ...  nonhispanic      M                Patras  Achaea  GR
#
#                            ADDRESS        CITY          STATE  \
# 0         422 Farrell Path Unit 69  Somerville  Massachusetts
# 1         422 Farrell Path Unit 69  Somerville  Massachusetts
# 2         422 Farrell Path Unit 69  Somerville  Massachusetts
# 3         422 Farrell Path Unit 69  Somerville  Massachusetts
# 4         422 Farrell Path Unit 69  Somerville  Massachusetts
# 5         422 Farrell Path Unit 69  Somerville  Massachusetts
# 6       427 Balistreri Way Unit 19    Chicopee  Massachusetts
# 7       427 Balistreri Way Unit 19    Chicopee  Massachusetts
# 8       427 Balistreri Way Unit 19    Chicopee  Massachusetts
# 9       427 Balistreri Way Unit 19    Chicopee  Massachusetts
# 10      427 Balistreri Way Unit 19    Chicopee  Massachusetts
# 11      427 Balistreri Way Unit 19    Chicopee  Massachusetts
# 12       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 13       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 14       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 15       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 16       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 17       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 18       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 19       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 20       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 21       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 22       1056 Harris Lane Suite 70    Chicopee  Massachusetts
# 23       1056 Harris Lane Suite 70    Chicopee  Massachusetts
#
# 33  Middlesex County  1851.0  42.636143 -71.343255
# 34  Middlesex County  1851.0  42.636143 -71.343255
# 35  Middlesex County  1851.0  42.636143 -71.343255
# 36  Middlesex County  1851.0  42.636143 -71.343255
# 37  Middlesex County  1851.0  42.636143 -71.343255
# 38  Middlesex County  1851.0  42.636143 -71.343255
# 39  Middlesex County  1851.0  42.636143 -71.343255
# 40  Middlesex County  1851.0  42.636143 -71.343255
# 41    Suffolk County  2135.0  42.352434 -71.028610
# 42    Suffolk County  2135.0  42.352434 -71.028610
# 43    Suffolk County  2135.0  42.352434 -71.028610
# 44    Suffolk County  2135.0  42.352434 -71.028610
# 45    Suffolk County  2135.0  42.352434 -71.028610
# 46    Suffolk County  2135.0  42.352434 -71.028610
#
# [47 rows x 28 columns]

# %%
df[df["PATIENT_ID"] == "71ba0469-f0cc-4177-ac70-ea07cb01c8b8"]
# Out:
#                                PATIENT_ID                 START  \
# 703  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2002-01-15T20:46:46Z
# 704  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2002-01-25T20:46:46Z
# 705  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2002-11-28T20:46:46Z
# 706  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2003-04-29T20:46:46Z
# 707  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2003-05-11T20:46:46Z
# ..                                    ...                   ...
# 783  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-05-08T20:46:46Z
# 784  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-05-08T20:46:46Z
# 785  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-05-08T20:46:46Z
# 786  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-08-14T20:46:46Z
# 787  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-11-20T20:46:46Z
#
#                      STOP ENCOUNTERCLASS  \
# 703  2002-01-15T21:01:46Z     ambulatory
# 704  2002-01-25T21:37:46Z     ambulatory
# 705  2002-12-12T20:46:46Z     ambulatory
# 706  2003-04-29T21:01:46Z       wellness
# 707  2003-05-11T21:01:46Z     ambulatory
# ..                    ...            ...
# 783  2012-05-08T21:01:46Z     ambulatory
# 784  2012-05-09T21:07:46Z      inpatient
# 785  2012-05-09T21:16:46Z      inpatient
# 786  2012-08-14T21:01:46Z     ambulatory
# 787  2012-11-20T21:01:46Z     ambulatory
#
#                                    DESCRIPTION  TOTAL_CLAIM_COST  \
# 703                      Encounter for problem            129.16
# 704                      Encounter for problem            129.16
# 705                      Encounter for symptom            129.16
# 706               Well child visit (procedure)            129.16
# 707                      Encounter for symptom            129.16
# ..                                         ...               ...
# 783  Postoperative follow-up visit (procedure)            129.16
# 784    Screening surveillance (regime/therapy)            129.16
# 785       Gynecology service (qualifier value)            129.16
# 786  Postoperative follow-up visit (procedure)            129.16
# 787  Postoperative follow-up visit (procedure)            129.16
#
#      PAYER_COVERAGE                                  REASONDESCRIPTION  \
# 703           54.16                                                NaN
# 704           54.16                                                NaN
# 705           54.16  Perennial allergic rhinitis with seasonal vari...
# 706           54.16                                                NaN
# 707           54.16               Streptococcal sore throat (disorder)
# ..              ...                                                ...
# 783           54.16            Malignant neoplasm of breast (disorder)
# 784           54.16            Malignant neoplasm of breast (disorder)
# 785           54.16            Malignant neoplasm of breast (disorder)
# 786           54.16            Malignant neoplasm of breast (disorder)
# 787           54.16            Malignant neoplasm of breast (disorder)
#
#       BIRTHDATE   DEATHDATE  ...    ETHNICITY GENDER              BIRTHPLACE  \
# 703  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 704  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 705  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 706  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 707  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# ..          ...         ...  ...          ...    ...                     ...
# 783  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 784  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 785  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 786  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 787  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
#
#                  ADDRESS     CITY          STATE            COUNTY ZIP  \
# 703  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 704  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 705  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 706  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 707  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# ..                   ...      ...            ...               ...  ..
# 783  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 784  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 785  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 786  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 787  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
#
#            LAT        LON
# 703  42.291986 -71.463724
# 704  42.291986 -71.463724
# 705  42.291986 -71.463724
# 706  42.291986 -71.463724
# 707  42.291986 -71.463724
# ..         ...        ...
# 783  42.291986 -71.463724
# 784  42.291986 -71.463724
# 785  42.291986 -71.463724
# 786  42.291986 -71.463724
# 787  42.291986 -71.463724
#
# [85 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53346 entries, 0 to 53345
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PATIENT_ID         53346 non-null  object
#  1   START              53346 non-null  object
#  2   STOP               53346 non-null  object
#  3   ENCOUNTERCLASS     53346 non-null  object
#  4   DESCRIPTION        53346 non-null  object
#  5   TOTAL_CLAIM_COST   53346 non-null  float64
#  6   PAYER_COVERAGE     53346 non-null  float64
#  7   REASONDESCRIPTION  13777 non-null  object
#  8   BIRTHDATE          53346 non-null  object
#  9   DEATHDATE          14287 non-null  object
#  10  SSN                53346 non-null  object
#  11  DRIVERS            49285 non-null  object
#  12  PASSPORT           46965 non-null  object
#  13  FIRST              53346 non-null  object
#  14  LAST               53346 non-null  object
#  15  MAIDEN             16597 non-null  object
#  16  MARITAL            43628 non-null  object
#  17  RACE               53346 non-null  object
#  18  ETHNICITY          53346 non-null  object
#  19  GENDER             53346 non-null  object
#  20  BIRTHPLACE         53346 non-null  object
#  21  ADDRESS            53346 non-null  object
#  22  CITY               53346 non-null  object
#  23  STATE              53346 non-null  object
#  24  COUNTY             53346 non-null  object
#  25  ZIP                28239 non-null  float64
#  26  LAT                53346 non-null  float64
#  27  LON                53346 non-null  float64
# dtypes: float64(5), object(23)
# memory usage: 11.4+ MB

# %%
gdf = gd.GeoDataFrame(df, crs="EPSG:4326", geometry=gd.points_from_xy(df.LON, df.LAT))

# %%
import contextily as ctx
# reproject
#gdf = gdf.to_crs(epsg=3857)
ax = gdf.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax=ax, source=ctx.providers.Stamen.TonerLite, zoom=12)
ax.set_axis_off()

# %%
# Préciser les colonnes pour l'éloignement
suppression = ["SSN", "DRIVERS", "PASSPORT", "FIRST", "LAST", "MAIDEN", "ADDRESS", "ZIP"]
# Et les laisser tomber
df.drop(suppression, axis=1, inplace=True)

# %%
import uuid

str(uuid.uuid4())
# Out:
# 'fac0d98a-43c0-47dd-9871-a0081fe68087'

# %%
import numpy as np

sigma = 0.001 # l'écart-type, c'est-à-dire le degré de variation par rapport aux données originales que nous autorisons
mu = 1 # les données originales, considérées comme la "moyenne"

np.random.normal(mu, sigma)
# Out:
# 1.000311630761287

# %%
from collections import defaultdict

class Pseudonymise:
    
    def __init__(self, sigma=0.001):
        # Initialiser un dictionnaire par défaut, cela crée un élément de dictionnaire par défaut s'il n'existe pas
        # Nous utilisons cette méthode pour garantir l'intégrité des données tout en les rendant aléatoires
        # http://ikigomu.com/?p=28
        self.sigma = sigma
        self.mu = 0 # Nous voulons nous écarter de la vérité
        # Pseudo-patient dict
        self.pp = defaultdict(lambda: {"uuid":str(uuid.uuid4()),
                                       "lat": np.random.normal(self.mu, self.sigma),
                                       "lon": np.random.normal(self.mu, self.sigma)
                                      })
        
    def create_data(self, identities):
        """
        Pour chaque identité unique produire un UUID unique, et un gaussien randomisé "LAT" et "LON".

        Parameters
        ----------
        identities: liste des chaînes de caractères

        Returns
        -------
        dict
            Chaque entrée de dict contient un enregistrement contenant un "uuid" et un modificateur pour "lat" et "lon".
        """
        for _id in identities:
            self.pp[_id]
        return self.pp
    
    def redact(self, row):
        """
        Pour une ligne donnée dans un dataframe, retournez la version pseudonymisée de "PATIENT_ID", "LAT", "LON".
        
        Parameters:
        row : Ligne de la trame de données
        
        row:
        DataFrame tranche de ligne 
        """
        return [
            self.pp[row["PATIENT_ID"]]["uuid"],
            row["LAT"] + self.pp[row["PATIENT_ID"]]["lat"],
            row["LON"] + self.pp[row["PATIENT_ID"]]["lon"],
        ]

p = Pseudonymise()
pp_data = p.create_data(df["PATIENT_ID"])
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html
fields = ["PATIENT_ID", "LAT", "LON"]
df[fields] = df[fields].apply(p.redact, axis=1, result_type="expand")

# %%
gdf = gd.GeoDataFrame(df, crs="EPSG:4326", geometry=gd.points_from_xy(df.LON, df.LAT))
#gdf = gdf.to_crs(epsg=3857)
ax = gdf.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax=ax, source=ctx.providers.Stamen.TonerLite, zoom=12)
ax.set_axis_off()

# %%
df = df.copy()
# Convertir les champs de date en dates de pandas
for c in ["START", "STOP", "BIRTHDATE", "DEATHDATE"]:
    df[c] = df[c].apply(lambda x: pd.to_datetime(x, errors="coerce", dayfirst=True).date())
# Filtre pour le traitement médical final pour tous les patients décédés
df = df[df.STOP==df.DEATHDATE]
df.sort_values(by="STOP", inplace=True)
df.drop_duplicates(subset="PATIENT_ID", keep="last", inplace=True)
# Créer le DEATHAGE 
# Il s'agit d'un calcul TRÈS approximatif de l'âge au décès
df["DEATHAGE"] = df.DEATHDATE.apply(lambda x: x.year) - df.BIRTHDATE.apply(lambda x: x.year)
# Et tirez la répartition des décès, divisée en n bacs
df["DEATHAGE"].hist(bins=10)

# %%
#Anonymisation BIRTHDATE
from pandas.tseries.offsets import MonthEnd
from pandas.tseries.offsets import MonthBegin
df['BIRTHDATE_BEGIN']=pd.to_datetime(df['BIRTHDATE'], infer_datetime_format=True) + MonthBegin(0)
df['BIRTHDATE_END']=pd.to_datetime(df['BIRTHDATE'], infer_datetime_format=True) + MonthEnd(1)
df['BIRTHDATE_INTERVAL']=df['BIRTHDATE_BEGIN'].astype(str) +'---'+df['BIRTHDATE_END'].astype(str)
df.drop(['BIRTHDATE_BEGIN','BIRTHDATE_END','BIRTHDATE'], axis=1, inplace=True)
df.head()
# Out:
#                                  PATIENT_ID       START        STOP  \
# 17464  e1b2239f-2424-4066-918b-d71b289adf61  1926-03-05  1926-03-05
# 6574   628ae54e-a2ad-49d7-aeb2-a207b08d4212  1927-07-08  1927-07-08
# 39451  4b7e7508-30e3-47bb-a85d-bca8826c524d  1958-01-03  1958-01-03
# 52548  b0a2c1d1-006a-498b-b585-f6207a902013  1962-12-29  1962-12-29
# 21413  f2b5712f-8b04-4a71-8a70-293240522754  1967-01-07  1967-01-07
#
#       ENCOUNTERCLASS          DESCRIPTION  TOTAL_CLAIM_COST  PAYER_COVERAGE  \
# 17464       wellness  Death Certification            129.16            0.00
# 6574        wellness  Death Certification            129.16            0.00
# 39451       wellness  Death Certification            129.16            0.00
# 52548       wellness  Death Certification            129.16            0.00
# 21413      emergency       Cardiac Arrest            129.16           69.16
#
#       REASONDESCRIPTION   DEATHDATE MARITAL  ... GENDER  \
# 17464               NaN  1926-03-05     NaN  ...      M
# 6574                NaN  1927-07-08     NaN  ...      M
# 39451               NaN  1958-01-03     NaN  ...      F
# 52548               NaN  1962-12-29     NaN  ...      M
# 21413               NaN  1967-01-07     NaN  ...      M
#
#                                 BIRTHPLACE       CITY          STATE  \
# 17464          Boylston  Massachusetts  US     Boston  Massachusetts
# 6574   West Springfield  Massachusetts  US  Brookline  Massachusetts
# 39451       Southbridge  Massachusetts  US    Hanover  Massachusetts
# 52548       New Bedford  Massachusetts  US   Westport  Massachusetts
# 21413          Brockton  Massachusetts  US    Chatham  Massachusetts
#
#                   COUNTY        LAT        LON                    geometry  \
# 17464     Suffolk County  42.204866 -71.127372  POINT (-71.12737 42.20487)
# 6574      Norfolk County  42.354413 -71.090987  POINT (-71.09099 42.35441)
# 39451    Plymouth County  42.083813 -70.828415  POINT (-70.82842 42.08381)
# 52548     Bristol County  41.598222 -71.066578  POINT (-71.06658 41.59822)
# 21413  Barnstable County  41.694488 -70.010565  POINT (-70.01057 41.69449)
#
#        DEATHAGE       BIRTHDATE_INTERVAL
# 17464        13  1913-06-01---1913-05-31
# 6574          4  1923-07-01---1923-06-30
# 39451        17  1941-03-01---1941-02-28
# 52548        10  1952-02-01---1952-01-31
# 21413        25  1942-06-01---1942-05-31
#
# [5 rows x 22 columns]

# %%
df['DEATHDATE_BEGIN']=pd.to_datetime(df['DEATHDATE'], infer_datetime_format=True) + MonthBegin(0)
df['DEATHDATE_END']=pd.to_datetime(df['DEATHDATE'], infer_datetime_format=True) + MonthEnd(1)
df['DEATHDATE_INTERVAL']=df['DEATHDATE_BEGIN'].astype(str) +'---'+df['DEATHDATE_END'].astype(str)
df.drop(['DEATHDATE_BEGIN','DEATHDATE_END','DEATHDATE'], axis=1, inplace=True)
df.head()
# Out:
#                                  PATIENT_ID       START        STOP  \
# 17464  e1b2239f-2424-4066-918b-d71b289adf61  1926-03-05  1926-03-05
# 6574   628ae54e-a2ad-49d7-aeb2-a207b08d4212  1927-07-08  1927-07-08
# 39451  4b7e7508-30e3-47bb-a85d-bca8826c524d  1958-01-03  1958-01-03
# 52548  b0a2c1d1-006a-498b-b585-f6207a902013  1962-12-29  1962-12-29
# 21413  f2b5712f-8b04-4a71-8a70-293240522754  1967-01-07  1967-01-07
#
#       ENCOUNTERCLASS          DESCRIPTION  TOTAL_CLAIM_COST  PAYER_COVERAGE  \
# 17464       wellness  Death Certification            129.16            0.00
# 6574        wellness  Death Certification            129.16            0.00
# 39451       wellness  Death Certification            129.16            0.00
# 52548       wellness  Death Certification            129.16            0.00
# 21413      emergency       Cardiac Arrest            129.16           69.16
#
#       REASONDESCRIPTION MARITAL    RACE  ...  \
# 17464               NaN     NaN   black  ...
# 6574                NaN     NaN   white  ...
# 39451               NaN     NaN   black  ...
# 52548               NaN     NaN   white  ...
# 21413               NaN     NaN  native  ...
#
#                                 BIRTHPLACE       CITY          STATE  \
# 17464          Boylston  Massachusetts  US     Boston  Massachusetts
# 6574   West Springfield  Massachusetts  US  Brookline  Massachusetts
# 39451       Southbridge  Massachusetts  US    Hanover  Massachusetts
# 52548       New Bedford  Massachusetts  US   Westport  Massachusetts
# 21413          Brockton  Massachusetts  US    Chatham  Massachusetts
#
#                   COUNTY        LAT        LON                    geometry  \
# 17464     Suffolk County  42.204866 -71.127372  POINT (-71.12737 42.20487)
# 6574      Norfolk County  42.354413 -71.090987  POINT (-71.09099 42.35441)
# 39451    Plymouth County  42.083813 -70.828415  POINT (-70.82842 42.08381)
# 52548     Bristol County  41.598222 -71.066578  POINT (-71.06658 41.59822)
# 21413  Barnstable County  41.694488 -70.010565  POINT (-70.01057 41.69449)
#
#        DEATHAGE       BIRTHDATE_INTERVAL       DEATHDATE_INTERVAL
# 17464        13  1913-06-01---1913-05-31  1926-04-01---1926-03-31
# 6574          4  1923-07-01---1923-06-30  1927-08-01---1927-07-31
# 39451        17  1941-03-01---1941-02-28  1958-02-01---1958-01-31
# 52548        10  1952-02-01---1952-01-31  1963-01-01---1962-12-31
# 21413        25  1942-06-01---1942-05-31  1967-02-01---1967-01-31
#
# [5 rows x 22 columns]

# %%
df['START_BEGIN']=pd.to_datetime(df['START'], infer_datetime_format=True) + MonthBegin(0)
df['START_END']=pd.to_datetime(df['START'], infer_datetime_format=True) + MonthEnd(1)
df['START_INTERVAL']=df['START_BEGIN'].astype(str) +'---'+df['START_END'].astype(str)
df.drop(['START_BEGIN','START_END','START'], axis=1, inplace=True)
df.head()
# Out:
#                                  PATIENT_ID        STOP ENCOUNTERCLASS  \
# 17464  e1b2239f-2424-4066-918b-d71b289adf61  1926-03-05       wellness
# 6574   628ae54e-a2ad-49d7-aeb2-a207b08d4212  1927-07-08       wellness
# 39451  4b7e7508-30e3-47bb-a85d-bca8826c524d  1958-01-03       wellness
# 52548  b0a2c1d1-006a-498b-b585-f6207a902013  1962-12-29       wellness
# 21413  f2b5712f-8b04-4a71-8a70-293240522754  1967-01-07      emergency
#
#                DESCRIPTION  TOTAL_CLAIM_COST  PAYER_COVERAGE  \
# 17464  Death Certification            129.16            0.00
# 6574   Death Certification            129.16            0.00
# 39451  Death Certification            129.16            0.00
# 52548  Death Certification            129.16            0.00
# 21413       Cardiac Arrest            129.16           69.16
#
#       REASONDESCRIPTION MARITAL    RACE    ETHNICITY  ...       CITY  \
# 17464               NaN     NaN   black  nonhispanic  ...     Boston
# 6574                NaN     NaN   white  nonhispanic  ...  Brookline
# 39451               NaN     NaN   black  nonhispanic  ...    Hanover
# 52548               NaN     NaN   white  nonhispanic  ...   Westport
# 21413               NaN     NaN  native  nonhispanic  ...    Chatham
#
#                STATE             COUNTY        LAT        LON  \
# 17464  Massachusetts     Suffolk County  42.204866 -71.127372
# 6574   Massachusetts     Norfolk County  42.354413 -71.090987
# 39451  Massachusetts    Plymouth County  42.083813 -70.828415
# 52548  Massachusetts     Bristol County  41.598222 -71.066578
# 21413  Massachusetts  Barnstable County  41.694488 -70.010565
#
#                          geometry  DEATHAGE       BIRTHDATE_INTERVAL  \
# 17464  POINT (-71.12737 42.20487)        13  1913-06-01---1913-05-31
# 6574   POINT (-71.09099 42.35441)         4  1923-07-01---1923-06-30
# 39451  POINT (-70.82842 42.08381)        17  1941-03-01---1941-02-28
# 52548  POINT (-71.06658 41.59822)        10  1952-02-01---1952-01-31
# 21413  POINT (-70.01057 41.69449)        25  1942-06-01---1942-05-31
#
#             DEATHDATE_INTERVAL           START_INTERVAL
# 17464  1926-04-01---1926-03-31  1926-04-01---1926-03-31
# 6574   1927-08-01---1927-07-31  1927-08-01---1927-07-31
# 39451  1958-02-01---1958-01-31  1958-02-01---1958-01-31
# 52548  1963-01-01---1962-12-31  1963-01-01---1962-12-31
# 21413  1967-02-01---1967-01-31  1967-02-01---1967-01-31
#
# [5 rows x 22 columns]

# %%
df['STOP_BEGIN']=pd.to_datetime(df['STOP'], infer_datetime_format=True) + MonthBegin(0)
df['STOP_END']=pd.to_datetime(df['STOP'], infer_datetime_format=True) + MonthEnd(1)
df['STOP_INTERVAL']=df['STOP_BEGIN'].astype(str) +'---'+df['STOP_END'].astype(str)
df.drop(['STOP_BEGIN','STOP_END','STOP'], axis=1, inplace=True)
df.head()
# Out:
#                                  PATIENT_ID ENCOUNTERCLASS  \
# 17464  e1b2239f-2424-4066-918b-d71b289adf61       wellness
# 6574   628ae54e-a2ad-49d7-aeb2-a207b08d4212       wellness
# 39451  4b7e7508-30e3-47bb-a85d-bca8826c524d       wellness
# 52548  b0a2c1d1-006a-498b-b585-f6207a902013       wellness
# 21413  f2b5712f-8b04-4a71-8a70-293240522754      emergency
#
#                DESCRIPTION  TOTAL_CLAIM_COST  PAYER_COVERAGE  \
# 17464  Death Certification            129.16            0.00
# 6574   Death Certification            129.16            0.00
# 39451  Death Certification            129.16            0.00
# 52548  Death Certification            129.16            0.00
# 21413       Cardiac Arrest            129.16           69.16
#
#       REASONDESCRIPTION MARITAL    RACE    ETHNICITY GENDER  ...  \
# 17464               NaN     NaN   black  nonhispanic      M  ...
# 6574                NaN     NaN   white  nonhispanic      M  ...
# 39451               NaN     NaN   black  nonhispanic      F  ...
# 52548               NaN     NaN   white  nonhispanic      M  ...
# 21413               NaN     NaN  native  nonhispanic      M  ...
#
#                STATE             COUNTY        LAT        LON  \
# 17464  Massachusetts     Suffolk County  42.204866 -71.127372
# 6574   Massachusetts     Norfolk County  42.354413 -71.090987
# 39451  Massachusetts    Plymouth County  42.083813 -70.828415
# 52548  Massachusetts     Bristol County  41.598222 -71.066578
# 21413  Massachusetts  Barnstable County  41.694488 -70.010565
#
#                          geometry  DEATHAGE       BIRTHDATE_INTERVAL  \
# 17464  POINT (-71.12737 42.20487)        13  1913-06-01---1913-05-31
# 6574   POINT (-71.09099 42.35441)         4  1923-07-01---1923-06-30
# 39451  POINT (-70.82842 42.08381)        17  1941-03-01---1941-02-28
# 52548  POINT (-71.06658 41.59822)        10  1952-02-01---1952-01-31
# 21413  POINT (-70.01057 41.69449)        25  1942-06-01---1942-05-31
#
#             DEATHDATE_INTERVAL           START_INTERVAL  \
# 17464  1926-04-01---1926-03-31  1926-04-01---1926-03-31
# 6574   1927-08-01---1927-07-31  1927-08-01---1927-07-31
# 39451  1958-02-01---1958-01-31  1958-02-01---1958-01-31
# 52548  1963-01-01---1962-12-31  1963-01-01---1962-12-31
# 21413  1967-02-01---1967-01-31  1967-02-01---1967-01-31
#
#                  STOP_INTERVAL
# 17464  1926-04-01---1926-03-31
# 6574   1927-08-01---1927-07-31
# 39451  1958-02-01---1958-01-31
# 52548  1963-01-01---1962-12-31
# 21413  1967-02-01---1967-01-31
#
# [5 rows x 22 columns]

# %%
df2 = pd.read_csv("fichier_programmation.csv")
df2["LON"].unique()
# Out:
# array([-71.12653095, -72.56295055, -72.60884223, ..., -71.21362111,
#        -71.23546104, -71.24522427])

# %%
df2 = pd.read_csv("fichier_programmation.csv")
df2["LAT"].unique()
# Out:
# array([42.36069733, 42.22835382, 42.1816423 , ..., 42.2113642 ,
#        42.16714611, 42.23395951])

# %%
df2= pd.read_csv("fichier_programmation.csv")
df2["DEATHAGE"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-63fb4b3abe37> in <module>
#       1 df2= pd.read_csv("fichier_programmation.csv")
# ----> 2 df2[DEATHAGE].unique()
#
# NameError: name 'DEATHAGE' is not defined

# %%
df2= pd.read_csv("fichier_programmation.csv")
df2["GENDER"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
bins = [0,1000,2000,3000,4000,5000,700000,20000000,700000000]

df3 = pd.cut(df2['LON'], bins=bins).value_counts().sort_index()
df3=df3.to_frame()
df3
# Out:
#                        LON
# (0, 1000]                0
# (1000, 2000]             0
# (2000, 3000]             0
# (3000, 4000]             0
# (4000, 5000]             0
# (5000, 700000]           0
# (700000, 20000000]       0
# (20000000, 700000000]    0

# %%
bins = [0,1000,2000,3000,4000,5000,700000,20000000,700000000]

df3 = pd.cut(df2['LAT'], bins=bins).value_counts().sort_index()
df3=df3.to_frame()
df3
# Out:
#                          LAT
# (0, 1000]              53346
# (1000, 2000]               0
# (2000, 3000]               0
# (3000, 4000]               0
# (4000, 5000]               0
# (5000, 700000]             0
# (700000, 20000000]         0
# (20000000, 700000000]      0
